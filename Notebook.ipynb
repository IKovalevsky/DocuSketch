# %%
import matplotlib.pyplot as plt

# %%
plot_paths = ["plots/gt_corners.png", "plots/rb_corners.png", "plots/mean.png", "plots/max.png", "plots/min.png"]

# %%
# Visualize the plots
for plot_path in plot_paths:
    image = plt.imread(plot_path)
    plt.figure()
    plt.imshow(image)
    plt.axis('off')
    plt.show()
